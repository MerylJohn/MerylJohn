# %% [markdown]
# <a href="https://colab.research.google.com/github/MerylJohn/MerylJohn/blob/main/Untitled22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
data=files.upload()
# Out:
#      <input type="file" id="files-b276fe9e-c03c-408e-8837-ab4bb89dc27e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b276fe9e-c03c-408e-8837-ab4bb89dc27e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
dataframe=pd.read_csv("diabetes.csv")

# %%
dataframe.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
x=dataframe.drop('Outcome',1)
y=dataframe.Outcome
# Out:
# <ipython-input-4-e7aae454f8b8>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   x=dataframe.drop('Outcome',1)

# %%
print(x)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=50)

# %%
from sklearn.tree import DecisionTreeClassifier
tree=DecisionTreeClassifier()
tree=tree.fit(X_train,y_train)
predictedy=tree.predict(X_test)

# %%
from sklearn import metrics
accuracy=metrics.accuracy_score(y_test,predictedy)
print(accuracy)
# Out:
# 0.7012987012987013

# %%
from sklearn.tree import export_graphviz
from io import StringIO

# %%
dodata=StringIO()
export_graphviz(tree,out_file=dodata,filled=True, rounded=True, special_characters=True,class_names=['0','1'])
print(dodata.getvalue())
# Out:
# digraph Tree {
# node [shape=box, style="filled, rounded", color="black", fontname="helvetica"] ;
# edge [fontname="helvetica"] ;
# 0 [label=<X<SUB>1</SUB> &le; 127.5<br/>gini = 0.452<br/>samples = 537<br/>value = [352, 185]<br/>class = 0>, fillcolor="#f3c3a1"] ;
# 1 [label=<X<SUB>7</SUB> &le; 39.5<br/>gini = 0.282<br/>samples = 324<br/>value = [269, 55]<br/>class = 0>, fillcolor="#ea9b61"] ;
# 0 -> 1 [labeldistance=2.5, labelangle=45, headlabel="True"] ;
# 2 [label=<X<SUB>0</SUB> &le; 6.5<br/>gini = 0.2<br/>samples = 258<br/>value = [229, 29]<br/>class = 0>, fillcolor="#e89152"] ;
# 1 -> 2 ;
# 3 [label=<X<SUB>5</SUB> &le; 48.25<br/>gini = 0.16<br/>samples = 240<br/>value = [219, 21]<br/>class = 0>, fillcolor="#e78d4c"] ;
# 2 -> 3 ;
# 4 [label=<X<SUB>5</SUB> &le; 30.75<br/>gini = 0.141<br/>samples = 236<br/>value = [218, 18]<br/>class = 0>, fillcolor="#e78b49"] ;
# 3 -> 4 ;
# ...

# %%
import pydotplus
graph=pydotplus.graph_from_dot_data(dodata.getvalue())
graph.write_png("tree for diabetes png")
# Out:
# True

# %%
from IPython.display import Image
Image(graph.create_png())
